# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_example = cv2.imread('./test/3.PNG',1)
img_example = np.argmax(img_example,axis=-1)
# img_example[img_example==1]=70
img_example[img_example==2]=1
# img_example[img_example==3]=150
# img_example[img_example==4]=200
# img_example[img_example==5]=250

# %%
print(np.unique(img_example))
print(img_example.shape)
# Out:
# [0 1]
# (480, 640)

# %%
plt.figure(figsize=(12,12))
plt.imshow(img_example, cmap='viridis')

# %%
img_example = cv2.imread('./3.PNG',cv2.IMREAD_ANYDEPTH)
plt.figure(figsize=(12,12))
plt.imshow(img_example)

# %%
print(np.unique(img_example))
# Out:
# [ 76 182 183 184 185 186 187 189 190 191 192 193 194 195 196 197 198 200
#  201 202 203 204 205 206 207 208 255]
